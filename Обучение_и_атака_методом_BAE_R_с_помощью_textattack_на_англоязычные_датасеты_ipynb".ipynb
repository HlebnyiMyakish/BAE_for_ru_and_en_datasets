# %% [markdown]
# # TextAttack End-to-End BAE-R
# Код использовался в google collab

# %%
# !pip3 install textattack[tensorflow]

# %%
# !pip install tensorflow==2.14

# %% [markdown]
# ## Training
#
# First, we're going to train a model. TextAttack integrates directly with [transformers](https://github.com/huggingface/transformers/) and [datasets](https://github.com/huggingface/datasets) to train any of the `transformers` pre-trained models on datasets from `datasets`.
#
# Let's use the Rotten Tomatoes Movie Review dataset: it's relatively short , and showcasesthe key features of `textattack train`. Let's take a look at the dataset using `textattack peek-dataset`:

# %%
#!textattack peek-dataset --dataset imdb
#!textattack peek-dataset --dataset-from-huggingface "imdb" #"Q-b1t/IMDB-Dataset-of-50K-Movie-Reviews-Backup" #--dataset_columns "sentiment","review"
#AlexSham/yelp_filtered
#AlexSham/imdb_filtered
#AlexSham/amazon_cells_filtered
# !textattack peek-dataset --dataset-from-huggingface "AlexSham/amazon_cells_filtered" #"Q-b1t/IMDB-Dataset-of-50K-Movie-Reviews-Backup" #--dataset_columns "sentiment","review"
# Out:
# 2024-04-16 15:10:56.806814: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 15:10:56.806879: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 15:10:56.806939: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-16 15:10:57.975412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
# ...

# %%
# !textattack train -h

# %%
# !textattack train --model-name-or-path bert-base-cased --dataset "AlexSham/amazon_cells_filtered" --model-num-labels 2 --model-max-length 64 --per-device-train-batch-size 128 --num-epochs 15
# Out:
# 2024-04-16 15:11:16.344984: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 15:11:16.345045: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 15:11:16.345097: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-16 15:11:17.986830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# textattack: Loading transformers AutoModelForSequenceClassification: bert-base-cased
# ...

# %% [markdown]
# ## Evaluation
#
# We successfully fine-tuned `distilbert-base-cased` for 3 epochs. Now let's evaluate it using `textattack eval`. This is as simple as providing the path to the pretrained model (that you just obtain from running the above command!) to `--model`, along with the number of evaluation samples. `textattack eval` will automatically load the evaluation data from training:

# %%
# !textattack eval -h

# %%
# !textattack eval --num-examples 100 --model ./outputs/2024-04-16-15-11-21-969510/best_model/ --dataset-from-huggingface "AlexSham/amazon_cells_filtered" --dataset-split test
# Out:
# 2024-04-16 15:15:13.262278: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 15:15:13.262330: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 15:15:13.262380: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-16 15:15:14.561844: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
# ...

# %% [markdown]
# ## Attack

# %%
# !pip3 install textattack[tensorflow]

# %%
# !pip install tensorflow==2.14

# %%
# !textattack attack --recipe textfooler --num-examples 100 --model ./outputs/2024-04-16-15-02-13-648740/best_model/ --dataset-from-huggingface "AlexSham/yelp_filtered" --dataset-split test

# %%
# !textattack attack --recipe bae --num-examples 100 --model ./outputs/2024-04-16-15-11-21-969510/best_model/ --dataset-from-huggingface "AlexSham/amazon_cells_filtered" --dataset-split test
# Out:
# 2024-04-16 15:15:40.326257: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-16 15:15:40.326323: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-16 15:15:40.326380: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-16 15:15:41.836822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/repocard.py:105: UserWarning: Repo card metadata block was not found. Setting CardData to empty.
# ...
